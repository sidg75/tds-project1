# %% [markdown]
# <a href="https://colab.research.google.com/github/sidg75/tds-project1/blob/main/tds_project1_git_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv

# GitHub API token
GITHUB_TOKEN = 'REMOVED' # Refer sidg75 github profile to know the code


# API URLs
SEARCH_URL = 'https://api.github.com/search/users'
USER_URL = 'https://api.github.com/users/'
REPO_URL = 'https://api.github.com/users/{}/repos'

# Headers for authorization
HEADERS = {
    'Authorization': f'Bearer {GITHUB_TOKEN}',
    'Accept': 'application/vnd.github+json'
}

# Function to clean up company names
def clean_company(company):
    if company:
        company = company.strip()  # Trim whitespace
        if company.startswith('@'):
            company = company[1:]  # Remove leading '@'
        company = company.upper()  # Convert to uppercase
    return company

# Function to write data to CSV
def write_to_csv(lst, file_name, header):
    with open(file_name, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(header)  # Write the header row
        writer.writerows(lst)    # Write the data rows

# Fetch users based on location and follower criteria
def fetch_users(loc, followers):
    page = 1
    users = []

    while True:
        params = {
            'q': f'location:Sydney followers:>100',  # Dynamic follower count
            'per_page': 100,
            'page': page
        }

        response = requests.get(SEARCH_URL, headers=HEADERS, params=params)

        if response.status_code == 200:

            result = response.json()
            print(result)
            print(f"Fetched {len(result['items'])} users on page {page}")
            users.extend(result['items'])  # Add the users to the list

            if len(result['items']) < 100:
                break  # No more pages, stop pagination

            page += 1  # Go to the next page
        else:
            print(f"Failed to fetch users: {response.status_code}, {response.text}")
            break

    return users

# Fetch detailed user info
def get_user_details(loginid):
    response = requests.get(f'https://api.github.com/users/{loginid}', headers=HEADERS)

    if response.status_code == 200:
        user_data = response.json()
        return [
            user_data.get('login', ''),
            user_data.get('name', ''),
            clean_company(user_data.get('company', '')),
            user_data.get('location', ''),
            user_data.get('email', ''),
            str(user_data.get('hireable', '')).lower(),
            user_data.get('bio', ''),
            user_data.get('public_repos', 0),
            user_data.get('followers', 0),
            user_data.get('following', 0),
            user_data.get('created_at', '')
        ]
    else:
        print(f"Failed to fetch user details for {loginid}: {response.status_code}")
        return None

# Fetch repository details for each user
# Function to fetch repositories for a user, paginated to 500
def get_user_repo_details(loginid):
    all_repo_data = []
    page = 1
    per_page = 100

    while len(all_repo_data) < 500:  # Limit to 500 repos
        response = requests.get(f'https://api.github.com/users/{loginid}/repos', headers=HEADERS, params={'per_page': per_page, 'page': page})

        if response.status_code == 200:
            repo_data = response.json()

            if not repo_data:  # No more repos
                break

            for repo in repo_data:
                license_info = repo.get('license')
                license_name = license_info['key'] if license_info else None

                all_repo_data.append([
                    loginid,
                    repo.get('full_name', ''),
                    repo.get('created_at', ''),
                    repo.get('stargazers_count', 0),
                    repo.get('watchers_count', 0),
                    repo.get('language', ''),
                    str(repo.get('has_projects', '')).lower(),
                    str(repo.get('has_wiki', '')).lower(),
                    license_name
                ])

            page += 1  # Go to the next page

            if len(repo_data) < per_page:  # Fewer than 100 repos on this page, stop
                break
        else:
            print(f"Failed to fetch repos for {loginid}: {response.status_code}")
            break

    return all_repo_data[:500]  # Return up to 500 repos


# Main function
def main():
    # Fetch all users based on location and followers
    users = fetch_users('Sydney', 100)

    # Store user details
    user_details = []
    repo_details = []

    for user in users:
        login = user.get('login')

        # Fetch and store user details
        user_detail = get_user_details(login)
        if user_detail:
            user_details.append(user_detail)

        # Fetch and store repo details
        repo_data = get_user_repo_details(login)
        if repo_data:
            repo_details.extend(repo_data)  # Extend the list with all repos

    # Write users data to CSV
    user_header = ['login', 'name', 'company', 'location', 'email', 'hireable', 'bio', 'public_repos', 'followers', 'following', 'created_at']
    write_to_csv(user_details, 'users.csv', user_header)

    # Write repo data to CSV
    repo_header = ['login', 'full_name', 'created_at', 'stargazers_count', 'watchers_count', 'language', 'has_projects', 'has_wiki', 'license_name']
    write_to_csv(repo_details, 'repositories.csv', repo_header)

if __name__ == '__main__':
    main()
# Out:
# {'total_count': 371, 'incomplete_results': False, 'items': [{'login': 'nicknochnack', 'id': 5948934, 'node_id': 'MDQ6VXNlcjU5NDg5MzQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/5948934?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nicknochnack', 'html_url': 'https://github.com/nicknochnack', 'followers_url': 'https://api.github.com/users/nicknochnack/followers', 'following_url': 'https://api.github.com/users/nicknochnack/following{/other_user}', 'gists_url': 'https://api.github.com/users/nicknochnack/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nicknochnack/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nicknochnack/subscriptions', 'organizations_url': 'https://api.github.com/users/nicknochnack/orgs', 'repos_url': 'https://api.github.com/users/nicknochnack/repos', 'events_url': 'https://api.github.com/users/nicknochnack/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nicknochnack/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'brendangregg', 'id': 1101211, 'node_id': 'MDQ6VXNlcjExMDEyMTE=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1101211?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/brendangregg', 'html_url': 'https://github.com/brendangregg', 'followers_url': 'https://api.github.com/users/brendangregg/followers', 'following_url': 'https://api.github.com/users/brendangregg/following{/other_user}', 'gists_url': 'https://api.github.com/users/brendangregg/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/brendangregg/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/brendangregg/subscriptions', 'organizations_url': 'https://api.github.com/users/brendangregg/orgs', 'repos_url': 'https://api.github.com/users/brendangregg/repos', 'events_url': 'https://api.github.com/users/brendangregg/events{/privacy}', 'received_events_url': 'https://api.github.com/users/brendangregg/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'cornflourblue', 'id': 785317, 'node_id': 'MDQ6VXNlcjc4NTMxNw==', 'avatar_url': 'https://avatars.githubusercontent.com/u/785317?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cornflourblue', 'html_url': 'https://github.com/cornflourblue', 'followers_url': 'https://api.github.com/users/cornflourblue/followers', 'following_url': 'https://api.github.com/users/cornflourblue/following{/other_user}', 'gists_url': 'https://api.github.com/users/cornflourblue/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cornflourblue/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cornflourblue/subscriptions', 'organizations_url': 'https://api.github.com/users/cornflourblue/orgs', 'repos_url': 'https://api.github.com/users/cornflourblue/repos', 'events_url': 'https://api.github.com/users/cornflourblue/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cornflourblue/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': '0vm', 'id': 79897291, 'node_id': 'MDQ6VXNlcjc5ODk3Mjkx', 'avatar_url': 'https://avatars.githubusercontent.com/u/79897291?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/0vm', 'html_url': 'https://github.com/0vm', 'followers_url': 'https://api.github.com/users/0vm/followers', 'following_url': 'https://api.github.com/users/0vm/following{/other_user}', 'gists_url': 'https://api.github.com/users/0vm/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/0vm/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/0vm/subscriptions', 'organizations_url': 'https://api.github.com/users/0vm/orgs', 'repos_url': 'https://api.github.com/users/0vm/repos', 'events_url': 'https://api.github.com/users/0vm/events{/privacy}', 'received_events_url': 'https://api.github.com/users/0vm/receiv ...
# Fetched 100 users on page 1
# {'total_count': 371, 'incomplete_results': False, 'items': [{'login': 'gloveboxes', 'id': 9853509, 'node_id': 'MDQ6VXNlcjk4NTM1MDk=', 'avatar_url': 'https://avatars.githubusercontent.com/u/9853509?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gloveboxes', 'html_url': 'https://github.com/gloveboxes', 'followers_url': 'https://api.github.com/users/gloveboxes/followers', 'following_url': 'https://api.github.com/users/gloveboxes/following{/other_user}', 'gists_url': 'https://api.github.com/users/gloveboxes/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gloveboxes/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gloveboxes/subscriptions', 'organizations_url': 'https://api.github.com/users/gloveboxes/orgs', 'repos_url': 'https://api.github.com/users/gloveboxes/repos', 'events_url': 'https://api.github.com/users/gloveboxes/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gloveboxes/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'itsdouges', 'id': 6801309, 'node_id': 'MDQ6VXNlcjY4MDEzMDk=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801309?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/itsdouges', 'html_url': 'https://github.com/itsdouges', 'followers_url': 'https://api.github.com/users/itsdouges/followers', 'following_url': 'https://api.github.com/users/itsdouges/following{/other_user}', 'gists_url': 'https://api.github.com/users/itsdouges/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/itsdouges/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/itsdouges/subscriptions', 'organizations_url': 'https://api.github.com/users/itsdouges/orgs', 'repos_url': 'https://api.github.com/users/itsdouges/repos', 'events_url': 'https://api.github.com/users/itsdouges/events{/privacy}', 'received_events_url': 'https://api.github.com/users/itsdouges/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'Showfom', 'id': 6773591, 'node_id': 'MDQ6VXNlcjY3NzM1OTE=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6773591?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Showfom', 'html_url': 'https://github.com/Showfom', 'followers_url': 'https://api.github.com/users/Showfom/followers', 'following_url': 'https://api.github.com/users/Showfom/following{/other_user}', 'gists_url': 'https://api.github.com/users/Showfom/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Showfom/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Showfom/subscriptions', 'organizations_url': 'https://api.github.com/users/Showfom/orgs', 'repos_url': 'https://api.github.com/users/Showfom/repos', 'events_url': 'https://api.github.com/users/Showfom/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Showfom/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'jesstelford', 'id': 612020, 'node_id': 'MDQ6VXNlcjYxMjAyMA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/612020?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jesstelford', 'html_url': 'https://github.com/jesstelford', 'followers_url': 'https://api.github.com/users/jesstelford/followers', 'following_url': 'https://api.github.com/users/jesstelford/following{/other_user}', 'gists_url': 'https://api.github.com/users/jesstelford/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jesstelford/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jesstelford/subscriptions', 'organizations_url': 'https://api.github.com/users/jesstelford/orgs', 'repos_url': 'https://api.github.com/users/jesstelford/repos', 'events_url': 'https://api.github.com/users/jesstelford/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jesstelford/received_events', 'type': 'User', 'user_view ...
# Fetched 100 users on page 2
# {'total_count': 371, 'incomplete_results': False, 'items': [{'login': 'siliconjungle', 'id': 71357672, 'node_id': 'MDQ6VXNlcjcxMzU3Njcy', 'avatar_url': 'https://avatars.githubusercontent.com/u/71357672?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/siliconjungle', 'html_url': 'https://github.com/siliconjungle', 'followers_url': 'https://api.github.com/users/siliconjungle/followers', 'following_url': 'https://api.github.com/users/siliconjungle/following{/other_user}', 'gists_url': 'https://api.github.com/users/siliconjungle/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/siliconjungle/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/siliconjungle/subscriptions', 'organizations_url': 'https://api.github.com/users/siliconjungle/orgs', 'repos_url': 'https://api.github.com/users/siliconjungle/repos', 'events_url': 'https://api.github.com/users/siliconjungle/events{/privacy}', 'received_events_url': 'https://api.github.com/users/siliconjungle/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'enzyme69', 'id': 3952687, 'node_id': 'MDQ6VXNlcjM5NTI2ODc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3952687?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/enzyme69', 'html_url': 'https://github.com/enzyme69', 'followers_url': 'https://api.github.com/users/enzyme69/followers', 'following_url': 'https://api.github.com/users/enzyme69/following{/other_user}', 'gists_url': 'https://api.github.com/users/enzyme69/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/enzyme69/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/enzyme69/subscriptions', 'organizations_url': 'https://api.github.com/users/enzyme69/orgs', 'repos_url': 'https://api.github.com/users/enzyme69/repos', 'events_url': 'https://api.github.com/users/enzyme69/events{/privacy}', 'received_events_url': 'https://api.github.com/users/enzyme69/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'jtblin', 'id': 1388974, 'node_id': 'MDQ6VXNlcjEzODg5NzQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1388974?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jtblin', 'html_url': 'https://github.com/jtblin', 'followers_url': 'https://api.github.com/users/jtblin/followers', 'following_url': 'https://api.github.com/users/jtblin/following{/other_user}', 'gists_url': 'https://api.github.com/users/jtblin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jtblin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jtblin/subscriptions', 'organizations_url': 'https://api.github.com/users/jtblin/orgs', 'repos_url': 'https://api.github.com/users/jtblin/repos', 'events_url': 'https://api.github.com/users/jtblin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jtblin/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'cxong', 'id': 1083215, 'node_id': 'MDQ6VXNlcjEwODMyMTU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1083215?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cxong', 'html_url': 'https://github.com/cxong', 'followers_url': 'https://api.github.com/users/cxong/followers', 'following_url': 'https://api.github.com/users/cxong/following{/other_user}', 'gists_url': 'https://api.github.com/users/cxong/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cxong/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cxong/subscriptions', 'organizations_url': 'https://api.github.com/users/cxong/orgs', 'repos_url': 'https://api.github.com/users/cxong/repos', 'events_url': 'https://api.github.com/users/cxong/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cxong/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {' ...
# Fetched 100 users on page 3
# {'total_count': 371, 'incomplete_results': False, 'items': [{'login': 'gsherwood', 'id': 185976, 'node_id': 'MDQ6VXNlcjE4NTk3Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/185976?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gsherwood', 'html_url': 'https://github.com/gsherwood', 'followers_url': 'https://api.github.com/users/gsherwood/followers', 'following_url': 'https://api.github.com/users/gsherwood/following{/other_user}', 'gists_url': 'https://api.github.com/users/gsherwood/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gsherwood/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gsherwood/subscriptions', 'organizations_url': 'https://api.github.com/users/gsherwood/orgs', 'repos_url': 'https://api.github.com/users/gsherwood/repos', 'events_url': 'https://api.github.com/users/gsherwood/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gsherwood/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'terrywang', 'id': 119261, 'node_id': 'MDQ6VXNlcjExOTI2MQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/119261?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/terrywang', 'html_url': 'https://github.com/terrywang', 'followers_url': 'https://api.github.com/users/terrywang/followers', 'following_url': 'https://api.github.com/users/terrywang/following{/other_user}', 'gists_url': 'https://api.github.com/users/terrywang/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/terrywang/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/terrywang/subscriptions', 'organizations_url': 'https://api.github.com/users/terrywang/orgs', 'repos_url': 'https://api.github.com/users/terrywang/repos', 'events_url': 'https://api.github.com/users/terrywang/events{/privacy}', 'received_events_url': 'https://api.github.com/users/terrywang/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'gscales', 'id': 11398797, 'node_id': 'MDQ6VXNlcjExMzk4Nzk3', 'avatar_url': 'https://avatars.githubusercontent.com/u/11398797?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gscales', 'html_url': 'https://github.com/gscales', 'followers_url': 'https://api.github.com/users/gscales/followers', 'following_url': 'https://api.github.com/users/gscales/following{/other_user}', 'gists_url': 'https://api.github.com/users/gscales/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gscales/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gscales/subscriptions', 'organizations_url': 'https://api.github.com/users/gscales/orgs', 'repos_url': 'https://api.github.com/users/gscales/repos', 'events_url': 'https://api.github.com/users/gscales/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gscales/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'score': 1.0}, {'login': 'damncabbage', 'id': 133028, 'node_id': 'MDQ6VXNlcjEzMzAyOA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/133028?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/damncabbage', 'html_url': 'https://github.com/damncabbage', 'followers_url': 'https://api.github.com/users/damncabbage/followers', 'following_url': 'https://api.github.com/users/damncabbage/following{/other_user}', 'gists_url': 'https://api.github.com/users/damncabbage/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/damncabbage/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/damncabbage/subscriptions', 'organizations_url': 'https://api.github.com/users/damncabbage/orgs', 'repos_url': 'https://api.github.com/users/damncabbage/repos', 'events_url': 'https://api.github.com/users/damncabbage/events{/privacy}', 'received_events_url': 'https://api.github.com/users/damncabbage/received_events', 'type': 'User', 'user_view_type': 'publi ...
# Fetched 71 users on page 4
